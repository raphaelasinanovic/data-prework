# %%
#import random
#gestures=["rock","paper","scissors"]
#n_rounds=0 
#rounds_to_win=2
#cpu_score=0
#player_score=0
#winner_round=()


while n_rounds <5 and cpu_score < rounds_to_win and player_score < rounds_to_win:
    
    #player_choice=input("Your turn. Please choose your gesture: ")

    #while player_choice!="scissors" and player_choice!="rock" and player_choice!="paper":
        print("Please choose one of those gestures: rock, paper or scissors!")
        player_choice=input("Your turn. Please choose your gesture: ")
   
    #print("You chose: {}".format(player_choice))

    #random_number=random.randint(0,2)
    #if random_number==0:
        cpu_choice="rock"
    #elif random_number==1:
        cpu_choice="paper"
    #else:
        cpu_choice="scissors"
    #print("The computer chose: {}".format(cpu_choice))
   
    
    if player_choice=="scissors" and cpu_choice=="rock":
        winner_round=1 
    elif player_choice=="scissors" and cpu_choice=="paper":
        winner_round=2
    elif player_choice=="rock" and cpu_choice=="paper":
        winner_round=1 
    elif player_choice=="rock" and cpu_choice=="scissors":
        winner_round=2
    elif player_choice=="paper" and cpu_choice=="rock":
        winner_round=2
    elif player_choice=="paper" and cpu_choice=="scissors":
        winner_round=1 
    else: 
        winner_round=0
    n_rounds+=1
    
    if winner_round==1:
        cpu_score+=1
        print("The Computer won the round")
    elif winner_round==2:
        player_score+=1
        print("You won the round")
    else: 
        print("It's a tie.")

    print("Your score: {}. The computer's score: {}".format(player_score,cpu_score))
if player_score > cpu_score:
    print("You won the game")
elif cpu_score > player_score:
    print("The computer won the game")
else:
    print("It's a tie!")
